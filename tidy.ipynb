# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('contoh_dataset.csv', sep=";")
df.head()
# Out:
#       Province   Age       Wage Life Insured
# 0       Banten  24.0  5000000.0          Yes
# 1  DKI Jakarta   NaN  3400000.0           No
# 2   Jawa Barat  60.0  7350000.0           No
# 3       Banten  34.0  3500000.0           No
# 4   Jawa Barat  58.0        NaN          Yes

# %%
df_long = pd.melt(df, id_vars='Province')
df_long
# Out:
#        Province      variable     value
# 0        Banten           Age        24
# 1   DKI Jakarta           Age       NaN
# 2    Jawa Barat           Age        60
# 3        Banten           Age        34
# 4    Jawa Barat           Age        58
# 5   DKI Jakarta           Age       NaN
# 6        Banten           Age        21
# 7        Banten           Age        44
# 8    Jawa Barat           Age        40
# 9   DKI Jakarta           Age        51
# 10       Banten           Age        32
# 11       Banten           Age        30
# 12   Jawa Barat           Age        30
# 13  DKI Jakarta           Age        19
# 14  DKI Jakarta           Age        25
# 15       Banten          Wage     5e+06
# 16  DKI Jakarta          Wage   3.4e+06
# 17   Jawa Barat          Wage  7.35e+06
# 18       Banten          Wage   3.5e+06
# 19   Jawa Barat          Wage       NaN
# 20  DKI Jakarta          Wage     8e+06
# 21       Banten          Wage   5.5e+06
# ...
